# %% [markdown]
# <a href="https://colab.research.google.com/github/Harbringe/VAP-Data-science/blob/main/Data_analytics_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Rohit Kulthe
# Div: A
# Roll no. 40

# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([23, 32, 3, 1, 5, 5])
arr
# Out:
# array([23, 32,  3,  1,  5,  5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Series

# %%
s = pd.Series([3, 5, 3, 4, 5])
s
# Out:
# 0    3
# 1    5
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 5

# %%
s.shape
# Out:
# (5,)

# %% [markdown]
# ## DataFrame

# %%
r = pd.Series([1,2,3,4,5])
n = pd.Series(['test1', 'test2', 'test3', 'test4', 'test5'])
m = pd.Series([65.423, 32.5 ,52,23.5, 23.23, 52.34])

# %%
df = pd.DataFrame({
    'roll' : r,
    'name' : n,
    'marks' : m
    }
)

# %%
df
# Out:
#    roll   name   marks
# 0   1.0  test1  65.423
# 1   2.0  test2  32.500
# 2   3.0  test3  52.000
# 3   4.0  test4  23.500
# 4   5.0  test5  23.230
# 5   NaN    NaN  52.340

# %%
df.shape
# Out:
# (6, 3)

# %%
df.size
# Out:
# 18

# %%
df.dtypes
# Out:
# roll     float64
# name      object
# marks    float64
# dtype: object

# %% [markdown]
# ## Structured Data analysis

# %%
df = pd.read_csv('student.csv' )

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df2 = pd.read_csv('student3.tsv', sep = "\t")

# %%
df2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df3 = pd.read_csv('https://gist.githubusercontent.com/justimchung/9b98c69b30600a46daa6d2e827c31b56/raw/4b1f08ba9b00a2fcd3f7ced9cf9e59062f489c3a/student.csv')

# %%
df3
# Out:
#   Unnamed: 0    Name  height  weight  sex       bdate       city major
# 0   s1234567   Peter   175.0   70.45    1   1980/4/30     Tainan  CSIE
# 1   e1234567    Mary   163.0   55.00    2  1981/12/21     Taipei    EE
# 2   f1357689    John   180.4   80.30    1   1980/5/30     Tainan  Stat
# 3   e1374659   Keven   182.5   77.60    1  1980/11/19     Taipei    EE
# 4   s7758347    JoJo   170.3   50.30    2   1980/1/27     Taipei  CSIE
# 5   s1334987   Emily   168.5   53.60    2  1982/10/13  Kaohsiung  CSIE
# 6   e1384726  Ubuntu   177.0   68.30    1    1981/7/6  Kaohsiung    EE

# %%
df4 = pd.read_excel('student.xlsx')

# %%
df4
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.ndim
# Out:
# 2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21
